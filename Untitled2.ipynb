# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham-1-cell/Crime_Mapping_And_Prediction/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chart_studio
# Out:
# Collecting chart_studio
#   Downloading https://files.pythonhosted.org/packages/ca/ce/330794a6b6ca4b9182c38fc69dd2a9cbff60fd49421cb8648ee5fee352dc/chart_studio-1.1.0-py3-none-any.whl (64kB)
#      |████████████████████████████████| 71kB 4.4MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from chart_studio) (2.23.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from chart_studio) (4.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->chart_studio) (3.0.4)
# Installing collected packages: chart-studio
# Successfully installed chart-studio-1.1.0

# %%
import pandas as pd 
import chart_studio.plotly as py 
import plotly.figure_factory as ff 
from  plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot 
import plotly.graph_objs as go 
import time 
import numpy as np 
from chart_studio.grid_objs import Grid, Column 
import cufflinks as cf

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
cf.go_offline() 
init_notebook_mode(connected=True)

# %%
df=pd.read_csv('/content/drive/MyDrive/Data Mining/district.csv')

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))
configure_plotly_browser_state()
#plotly figure is a dictonary with data and layout keys
#go is used to create graphical objects
figure = {
     'data' : [go.Bar( x=df['STATE/UT'],y=df['TOTAL IPC CRIMES'],name='TOTAL IPC CRIMES',marker=dict(color='rgb(200,200,210)')) ], 
     'layout' : {
         'title':'NUMBER OF CRIMES COMMITTED IN DIFFERENT STATES', 
         'paper_bgcolor':'rgb(0,0,0)',
         'plot_bgcolor':'rgb(10,10,10)',
         'font':dict(size=12, color='red'), 
         'titlefont':dict(size=24,family='Courier New, monospace'), 
         'height':620, 
         'margin':go.layout.Margin(b=130,pad=3),
         'xaxis':dict(title='State',tickfont=dict(size=10)), 
         'yaxis':dict(title='Number Of Crimes Committed') 
      }
}
iplot(figure)

# %%
#most committed crimes
s= df.sum(axis=0) 
s.drop(['STATE/UT','DISTRICT','YEAR','TOTAL IPC CRIMES','OTHER IPC CRIMES'],inplace=True)
temp = pd.DataFrame(s)
temp.columns=['SUM']
temp = temp.sort_values(by='SUM',ascending=False)
temp=temp.reset_index()
temp.columns=['Crime','Total'] 
print(temp)
# Out:
#                                                 Crime    Total
# 0                                               THEFT  7001060
# 1                                  HURT/GREVIOUS HURT  6743752
# 2                                         OTHER THEFT  4460320
# 3                                          AUTO THEFT  2540740
# 4                                            BURGLARY  2234678
# 5                         CAUSING DEATH BY NEGLIGENCE  2003728
# 6                 CRUELTY BY HUSBAND OR HIS RELATIVES  1750402
# 7                                               RIOTS  1549854
# 8                                            CHEATING  1535194
# 9   ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MO...   906310
# 10                                             MURDER   805086
# 11                             KIDNAPPING & ABDUCTION   713714
# 12                                  ATTEMPT TO MURDER   703954
# 13        KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS   527814
# 14                                            ROBBERY   496534
# 15                                               RAPE   478274
# 16                                         OTHER RAPE   478222
# 17                           CRIMINAL BREACH OF TRUST   368042
# 18                         INSULT TO MODESTY OF WOMEN   248108
# 19                                              ARSON   227408
# 20                 KIDNAPPING AND ABDUCTION OF OTHERS   185900
# 21                                       DOWRY DEATHS   182404
# 22                                            DACOITY   118818
# 23          CULPABLE HOMICIDE NOT AMOUNTING TO MURDER    89228
# 24               PREPARATION AND ASSEMBLY FOR DACOITY    63882
# 25                                     COUNTERFIETING    53436
# 26        IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES     1784
# 27                                     CUSTODIAL RAPE       52

# %%
configure_plotly_browser_state()
colorscale = [[0, '#FAEE1C'], [0.33, '#F3558E'], [0.66, '#9C1DE7'], [1, '#581B98']] 
tracel = {
    'data':[go.Scatter(
    x = temp['Crime'],
    y = temp['Total'],
    mode='markers', 
    marker=dict(
        size=15,
        color =np.random.randn(500), 
        colorscale=colorscale,
        showscale=True
        
    )
    )],
    'layout': { 
        'title':'NUMBER AND TYPES OF CRIME COMMITTED',
        'titlefont':dict(size=24,family='Courier New, monospace'),
        'height':600,
        'margin':go.layout.Margin(b=200),
        'xaxis':dict(title='CRIME',tickfont=dict(size=10)),
        'yaxis':dict(title='NUMBER OF CRIMES COMMITTED BY TYPE'), 
        'font':dict(size=12, color='#7f7f7f') 
    }
}
iplot(tracel)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="d505ca41-62f3-40b5-87f9-30594517ce61" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d505ca41-62f3-40b5-87f9-30594517ce61")) {
#                     Plotly.newPlot(
#                         'd505ca41-62f3-40b5-87f9-30594517ce61',
#                         [{"marker": {"color": [0.16788971873062453, -0.9907080155406617, 0.2743346821007301, -1.0352416724970812, 0.43282231711829516, -0.36809892206735373, -0.9349499731725475, 0.40995134989263676, -0.616690416810218, -0.278427473868707, 1.110838761782055, -1.3236742667019112, -0.09114918839314635, -0.6756520287843164, -1.7536471257182689, 0.8048703439769501, -1.9274003994978852, -0.4384872232365656, -0.4831100557114748, -1.125902693192852, -1.5172207036684635, 0.8488149307891368, 1.1021306503573294, -1.4784868075838278, 1.4475352518221427, -1.802665651395476, -0.4943288231405895, -0.9121586788639714, 0.6847346422653019, 1.4868193086242443, -0.3062771979399249, -0.6552155260380426, -0.8052887713886309, -1.0652391688574883, -0.8993035134432609, -0.3410719893388634, 0.404699710799358, 0.32110823322340165, -0.12498484742693605, 0.0976857520526366, 1.1450741130437494, -0.25553743619178965, 0.9438356008082529, 0.27324885036593466, 0.7261915514868128, 3.282876563034478, -1.446566874546528, 1.5471847420736993, -0.3345782069670777, -0.5093690360094928, 0.7160090775921037, -1.090299450099143, -0.024581845087196887, -1.1419438865885534, -0.2984405097382954, -0.42760965386769056, -0.2625852027593532, -0.34064598429617304, -2.465357364020774, -0.7011005201800649, 0.14303560488631734, 0.9932407633887185, 0.6393476866791243, -1.354347135727519, -0.1415241384794189, 1.429365940873651, -0.2539882022058463, -1.4128573655265257, -1.118283818899973, 0.7529534483420415, 0.28185154482785924, 1.264682771333814, 1.0659363229619823, 0.9213621475813805, -0.5416792874258097, 0.853647653793793, 0.5749218619268809, -1.0381469438081652, 1.3503783621923937, -0.9788248314618212, -0.8337873161159784, 0.2651333317927915, 0.7012782213235242, 0.3623163306121919, 1.4688582790757365, -0.8954537111532482, 0.3693997532910926, 1.3888452121529127, -1.6702598729138143, 1.6841332451050572, 1.5767174667071904, -0.3307596190705382, 0.24950203850855218, 1.628408718782468, 1.5459885713943846, -0.7452903859508052, -0.8782673812994506, 1.2485878335585678, 0.5257430037937671, 0.3050964825318459, -0.9037004371095485, -0.9384484992652147, 0.03610176017702621, 0.468879844465776, -1.1129137017661501, -0.35068445256668296, 0.19482849629820875, 1.5264185092972626, 1.484749034035422, -0.7418191176754673, -1.6155231704919164, 0.3036893840579571, 0.14130852437722585, 0.8103132388357084, -0.37945098369704255, -1.2969623879448169, 0.1455609488895956, 1.3405774582251264, -0.5670839601213568, -0.1906192916393597, 0.795121036025288, 0.46079289302931753, 2.0766271342442164, -0.9111456550339587, 0.43444838318511986, -0.23542659396304078, -0.5275824431030168, -1.0048534862363494, 0.901544563050282, 1.6359575968563, 0.32361003713315256, 0.026116735646114612, 1.0006303554174245, -0.3536250781025301, -0.5941606625045084, -0.35012700026848903, 0.429961948087163, 0.9035829892430766, -0.9410322322755645, -0.8464158051100149, -0.6538291721028194, -1.197219861891778, -0.5296241643640848, -0.063864757187618, -0.9402875282795918, -1.4028526205394645, 1.0431111857566226, 0.886820548938226, 0.9056057101209044, -1.1482570860035473, -0.5603594251966592, -0.5665451644377364, -1.1375672949132771, 0.680391374946462, 0.6655455997633084, 0.33410479638971863, -0.2996099047974379, -0.9735574347479575, 0.5112536171819538, 1.1177456413245062, 0.7430400029987235, 0.12644231630088867, 1.4002223749586453, 0.5915928756663186, 0.15985670511661557, 0.8184537245569308, 0.11426810919449122, -0.7485220565734723, 1.1797579664547793, 0.45632123725301177, -1.5940820873152428, -0.14123346245055163, -1.1005593696016849, 0.9991354991642087, -0.712294845975419, 0.20874897639158638, 0.10462377110373848, -0.8390712528827685, -0.1637637536784776, 0.5951918127765975, 1.1217962778151245, -0.8193017398083857, 0.2761570684396199, 0.6619820606841367, 0.47050739204841563, -1.0819898187049766, 1.0230423532251343, 1.681794032850512, -0.646840194261878, -0.3592439204962882, 0.774416885806646, 1.5322782163338344, 0.12005431126 ...

# %%
top5 = temp['Crime'][:5] 
temp = df.groupby(['STATE/UT','YEAR']).sum()
temp = temp.reset_index()
temp.drop('YEAR',axis=1,inplace=True) 
print(temp)
# Out:
#           STATE/UT  MURDER  ...  OTHER IPC CRIMES  TOTAL IPC CRIMES
# 0    A & N ISLANDS      26  ...               646              1316
# 1    A & N ISLANDS      34  ...               656              1216
# 2    A & N ISLANDS      42  ...               636              1288
# 3    A & N ISLANDS      30  ...               774              1496
# 4    A & N ISLANDS      28  ...               724              1364
# ..             ...     ...  ...               ...               ...
# 415    WEST BENGAL    3622  ...             76354            210838
# 416    WEST BENGAL    4136  ...             77552            226072
# 417    WEST BENGAL    4796  ...             98192            259232
# 418    WEST BENGAL    4218  ...            113228            286394
# 419    WEST BENGAL    4504  ...            128964            322854
#
# [420 rows x 31 columns]

# %%
configure_plotly_browser_state()

for i in top5:
     temp = temp.sort_values(by=i,ascending=False)
     figure = {
          'data':[go.Bar(
               x=temp['STATE/UT'],
               y=temp[i],
               marker=dict(color='rgb(200,200,210)')
     )],
     'layout' : { 
     'title':i, 
     'titlefont':dict(size=24,family='Courier New, monospace'),
     'height':600,
     'margin':go.layout.Margin(b=200),
     'paper_bgcolor':'rgb(0,0,0)',
     'plot_bgcolor':'rgb(10,10,10)',
     'xaxis':dict(title='STATE',tickfont=dict(size=10)), 
     'yaxis':dict(title='NUMBER OF CRIMES COMMITTED'),
     'font':dict(size=12, color='white') 
     } 
     } 
     iplot(figure)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="91355d9b-3ed7-4a18-a530-73d5ac54cad0" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
AT", "UTTAR PRADESH", "BIHAR", "UTTAR PRADESH", "UTTAR PRADESH", "BIHAR", "WEST BENGAL", "CHHATTISGARH", "GUJARAT", "UTTAR PRADESH", "GUJARAT", "CHHATTISGARH", "UTTAR PRADESH", "GUJARAT", "GUJARAT", "UTTAR PRADESH", "UTTAR PRADESH", "UTTAR PRADESH", "GUJARAT", "CHHATTISGARH", "GUJARAT", "GUJARAT", "CHHATTISGARH", "GUJARAT", "WEST BENGAL", "BIHAR", "BIHAR", "CHHATTISGARH", "ODISHA", "ODISHA", "UTTAR PRADESH", "BIHAR", "ODISHA", "ODISHA", "ODISHA", "WEST BENGAL", "ODISHA", "CHHATTISGARH", "CHHATTISGARH", "ASSAM", "ASSAM", "ASSAM", "WEST BENGAL", "ODISHA", "ASSAM", "ODISHA", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "PUNJAB", "PUNJAB", "PUNJAB", "CHHATTISGARH", "ASSAM", "ASSAM", "HARYANA", "PUNJAB", "HARYANA", "ASSAM", "ODISHA", "ODISHA", "PUNJAB", "JHARKHAND", "ASSAM", "ODISHA", "PUNJAB", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "CHHATTISGARH", "PUNJAB", "JHARKHAND", "PUNJAB", "ODISHA", "JHARKHAND", "PUNJAB", "HARYANA", "PUNJAB", "WEST BENGAL", "HARYANA", "JHARKHAND", "WEST BENGAL", "PUNJAB", "PUNJAB", "HARYANA", "CHHATTISGARH", "WEST BENGAL", "JHARKHAND", "CHHATTISGARH", "HARYANA", "WEST BENGAL", "CHHATTISGARH", "HARYANA", "HARYANA", "WEST BENGAL", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "TRIPURA", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "TRIPURA", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "UTTARAKHAND", "HIMACHAL PRADESH", "TRIPURA", "PUDUCHERRY", "PUDUCHERRY", "TRIPURA", "UTTARAKHAND", "PUDUCHERRY", "UTTARAKHAND", "UTTARAKHAND", "PUDUCHERRY", "TRIPURA", "PUDUCHERRY", "PUDUCHERRY", "UTTARAKHAND", "PUDUCHERRY", "UTTARAKHAND", "PUDUCHERRY", "UTTARAKHAND", "PUDUCHERRY", "UTTARAKHAND", "UTTARAKHAND", "PUDUCHERRY", "PUDUCHERRY", "UTTARAKHAND", "UTTARAKHAND", "UTTARAKHAND", "PUDUCHERRY", "TRIPURA", "TRIPURA", "ARUNACHAL PRADESH", "TRIPURA", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "TRIPURA", "TRIPURA", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "TRIPURA", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "TRIPURA", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "MANIPUR", "MANIPUR", "JAMMU & KASHMIR", "ARUNACHAL PRADESH", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMI ...
# <div>
#
#
#             <div id="97918163-f541-4d6e-87a8-16dc82d5b41c" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("97918163-f541-4d6e-87a8-16dc82d5b41c")) {
#                     Plotly.newPlot(
#                         '97918163-f541-4d6e-87a8-16dc82d5b41c',
#                         [{"marker": {"color": "rgb(200,200,210)"}, "type": "bar", "x": ["MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "UTTAR PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "WEST BENGAL", "ANDHRA PRADESH", "WEST BENGAL", "MADHYA PRADESH", "UTTAR PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "ANDHRA PRADESH", "UTTAR PRADESH", "WEST BENGAL", "MADHYA PRADESH", "WEST BENGAL", "UTTAR PRADESH", "MADHYA PRADESH", "MADHYA PRADESH",
"HIMACHAL PRADESH", "HIMACHAL PRADESH", "CHANDIGARH", "CHANDIGARH", "MIZORAM", "MIZORAM", "MIZORAM", "MIZORAM", "CHANDIGARH", "MIZORAM", "MIZORAM", "CHANDIGARH", "HIMACHAL PRADESH", "MIZORAM", "GOA", "CHANDIGARH", "GOA", "GOA", "CHANDIGARH", "MIZORAM", "HIMACHAL PRADESH", "CHANDIGARH", "CHANDIGARH", "MIZORAM", "MEGHALAYA", "HIMACHAL PRADESH", "GOA", "MEGHALAYA", "MEGHALAYA", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "TRIPURA", "HIMACHAL PRADESH", "TRIPURA", "TRIPURA", "HIMACHAL PRADESH", "ARUNACHAL PRADESH", "MEGHALAYA", "HIMACHAL PRADESH", "GOA", "ARUNACHAL PRAD ...
# <div>
#
#
#             <div id="60cd7a7e-f1d8-4e00-ad7a-472f3b95e204" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("60cd7a7e-f1d8-4e00-ad7a-472f3b95e204")) {
#                     Plotly.newPlot(
#                         '60cd7a7e-f1d8-4e00-ad7a-472f3b95e204',
#                         [{"marker": {"color": "rgb(200,200,210)"}, "type": "bar", "x": ["UTTAR PRADESH", "UTTAR PRADESH", "MAHARASHTRA", "MAHARASHTRA", "UTTAR PRADESH", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "UTTAR PRADESH", "DELHI UT", "DELHI UT", "DELHI UT", "RAJASTHAN", "MAHARASHTRA", "RAJASTHAN", "DELHI UT", "HARYANA", "MAHARASHTRA", "RAJASTHAN", "HARYANA", "MADHYA PRADESH", "MAHARASHTRA", "RAJASTHAN", "UTTAR PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MAHARASHTRA", "HARYANA", "GUJARAT", "KARNATAKA", "DELHI UT", "UTTAR PRADESH", "KARNATAKA", "MADHYA PRADESH", "MADHYA PRADESH", "KARNATAKA", "GUJARAT", "RAJASTHAN", "GUJARAT", "UTTAR PRADESH", "DELHI UT", "MAHARASHTRA", "MAHARASHTRA", "GUJARAT", "ANDHRA PRADESH", "KARNATAKA", "GUJARAT", "MADHYA PRADESH", "KARNATAKA", "DELHI UT", "DELHI UT", "MAHARASHTRA", "DELHI UT", "UTTAR PRADESH", "UTTAR PRADESH", "HARYANA", "RAJASTHAN", "ANDHRA PRADESH", "GUJARAT", "DELHI UT", "ANDHRA PRADESH", "HARYANA", "MADHYA PRADESH", "DELHI UT", "DELHI UT", "ANDHRA PRADESH", "ANDHRA PRADESH", "RAJASTHAN", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "RAJASTHAN", "RAJASTHAN", "HARYANA", "BIHAR", "MADHYA PRADESH", "UTTAR PRADESH", "HARYANA", "GUJARAT", "UTTAR PRADESH", "ANDHRA PRADESH", "MADHYA PRADESH", "KARNATAKA", "KARNATAKA", "KARNATAKA", "UTTAR PRADESH", "GUJARAT", "RAJASTHAN", "ANDHRA PRADESH", "ANDHRA PRADESH", "MADHYA PRADESH", "KARNATAKA", "WEST BENGAL", "TAMIL NADU", "ANDHRA PRADESH", "BIHAR", "HARYANA", "TAMIL NADU", "TAMIL NADU", "MADHYA PRADESH", "RAJASTHAN", "TAMIL NADU", "WEST BENGAL", "TAMIL NADU", "MADHYA PRADESH", "ANDHRA PRADESH", "TAMIL NADU", "KARNATAKA", "RAJASTHAN", "KARNATAKA", "BIHAR", "WEST BENGAL", "KARNATAKA", "TAMIL NADU", "TAMIL NADU", "HARYANA", "TAMIL NADU", "WEST BENGAL", "BIHAR", "TAMIL NADU", "ANDHRA PRADESH", "ODISHA", "HARYANA", "ANDHRA PRADESH", "HARYANA", "JHARKHAND", "ODISHA", "HARYANA", "TAMIL NADU", "TAMIL NADU", "ASSAM", "WEST BENGAL", "PUNJAB", "JHARKHAND", "BIHAR", "WEST BENGAL", "ODISHA", "WEST BENGAL", "WEST BENGAL", "WEST BENGAL", "ODISHA", "PUNJAB", "WEST BENGAL", "WEST BENGAL", "WEST BENGAL", "BIHAR", "CHHATTISGARH", "CHHATTISGARH", "JHARKHAND", "PUNJAB", "CHHATTISGARH", "JHARKHAND", "CHHATTISGARH", "BIHAR", "ASSAM", "CHHATTISGARH", "KERALA", "PUNJAB", "ASSAM", "PUNJAB", "BIHAR", "KERALA", "BIHAR", "KERALA", "PUNJAB", "ASSAM", "KERALA", "KERALA", "ODISHA", "KERALA", "JHARKHAND", "CHHATTISGARH", "KERALA", "JHARKHAND", "ODISHA", "KERALA", "ASSAM", "KERALA", "ODISHA", "CHHATTISGARH", "CHHATTISGARH", "ODISHA", "PUNJAB", "KERALA", "KERALA", "ODISHA", "PUNJAB", "ASSAM", "BIHAR", "CHHATTISGARH", "PUNJAB", "KERALA", "PUNJAB", "JHARKHAND", "PUNJAB", "JHARKHAND", "PUNJAB", "BIHAR", "CHANDIGARH", "CHANDIGARH", "ODISHA", "BIHAR", "ODISHA", "JAMMU & KASHMIR", "ASSAM", "UTTARAKHAND", "JAMMU & KASHMIR", "CHHATTISGARH", "CHHATTISGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHHATTISGARH", "JAMMU & KASHMIR", "UTTARAKHAND", "CHANDIGARH", "UTTARAKHAND", "ODISHA", "JHARKHAND", "MANIPUR", "UTTARAKHAND", "UTTARAKHAND", "JAMMU & KASHMIR", "ASSAM", "JAMMU & KASHMIR", "CHANDIGARH", "JAMMU & KASHMIR", "CHANDIGARH", "ASSAM", "CHANDIGARH", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "UTTARAKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "MANIPUR", "CHANDIGARH", "UTTARAKHAND", "CHANDIGARH", "UTTARAKHAND", "JAMMU & KASHMIR", "PUDUCHERRY", "JAMMU & KASHMIR", "PUDUCHERRY", "UTTARAKHAND", "PUDUCHERRY", "ASSAM", "CHANDIGARH", "GOA", "PUDUCHERRY", "PUDUCHERRY", "ASSAM", "UTTARAKHAND", "PUDUCHERRY", "UTTARAKHAND", "UTTARAKHAND", "GOA", "HIMACHAL PRADESH", "ASSAM", "GOA", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "PUDUCHERRY", "PUDUCHERRY", "GOA", "PUDUCHERRY", "PUDUCHERRY", "MANIPUR", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "PUDUCHERRY", "MANIPUR", "GOA", "PUDUCHERRY", "GOA", "MANIPUR", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "GOA", "NAGALAND", "HIMACHAL PRADESH", "MEGHALAYA", "GOA", "NAGALAND", "MEGHALAYA", "GOA", "HIMACHAL PR ...
# <div>
#
#
#             <div id="a4758896-e076-4f6a-b5ea-90ca8074e0f4" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a
"UTTARAKHAND", "UTTARAKHAND", "UTTARAKHAND", "UTTARAKHAND", "WEST BENGAL", "UTTARAKHAND", "UTTARAKHAND", "MIZORAM", "UTTARAKHAND", "WEST BENGAL", "WEST BENGAL", "MIZORAM", "WEST BENGAL", "MIZORAM", "MIZORAM", "WEST BENGAL", "MIZORAM", "UTTARAKHAND", "MIZORAM", "MIZORAM", "WEST BENGAL", "UTTARAKHAND", "WEST BENGAL", "MIZORAM", "GOA", "GOA", "CHANDIGARH", "UTTARAKHAND", "GOA", "GOA", "WEST BENGAL", "MIZORAM", "WEST BENGAL", "UTTARAKHAND", "MIZORAM", "MIZORAM", "CHANDIGARH", "WEST BENGAL", "GOA", "UTTARAKHAND", "GOA", "GOA", "GOA", "CHANDIGARH", "GOA", "ARUNACHAL PRADESH", "GOA", "GOA", "CHANDIGARH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "GOA", "MIZORAM", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "CHANDIGARH", "ARUNACHAL PRADESH", "TRIPURA", "CHANDIGARH" ...

# %%
configure_plotly_browser_state()
temp = temp.sort_values(by='STATE/UT') 

one = go.Bar( 
x=temp['STATE/UT' ] ,y=temp[top5[0]],name=top5[0],marker=dict(color='#ffcdd2') 
)
two = go.Bar(
x=temp['STATE/UT'],y=temp[top5[1]],name=top5[1],marker=dict(color='#A2D5F2') 
) 
three = go.Bar(
x=temp['STATE/UT'],y=temp[top5[2]],name=top5[2],marker=dict(color='#59606D') 
) 
four = go.Bar(
x=temp['STATE/UT'],y=temp[top5[3]],name=top5[3],marker=dict(color='#3459AD') 
) 
five = go.Bar(
x=temp['STATE/UT'],y=temp[top5[4]],name=top5[4],marker=dict(color='#f1606D') 
)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>

# %%
configure_plotly_browser_state()
data=[one,two,three,four,five] 
layout = {
    'title':'Comparative study of top 5 crimes', 
    'titlefont':dict(size=24,family='Courier New, monospace'),
    'height':600, 
    'width':2090, 
    'margin':go.layout.Margin(b=100), 
    'xaxis':dict(title='STATE',tickfont=dict(size=10)), 
    'yaxis':dict(title='NUMBER OF CRIMES COMMITTED'), 
    'font':dict(size=12, color='#7f7f7f') 
  }   
figure = go.Figure(data=data,layout=layout) 
iplot(figure)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="906d40f4-ea1b-48e3-8e26-6eed3bf4a137" class="plotly-graph-div" style="height:600px; width:2090px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("906d40f4-ea1b-48e3-8e26-6eed3bf4a137")) {
#                     Plotly.newPlot(
#                         '906d40f4-ea1b-48e3-8e26-6eed3bf4a137',
#                         [{"marker": {"color": "#ffcdd2"}, "name": "THEFT", "type": "bar", "x": ["A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "A & N ISLANDS", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ANDHRA PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ARUNACHAL PRADESH", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "ASSAM", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "BIHAR", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHANDIGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "CHHATTISGARH", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "D & N HAVELI", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DAMAN & DIU", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "DELHI UT", "GOA", "GOA", "GOA", "GOA", "GOA", "GOA", "GOA", "GOA", "GOA", "GOA", "GOA", "GOA", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "GUJARAT", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HARYANA", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "HIMACHAL PRADESH", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JAMMU & KASHMIR", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "JHARKHAND", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KARNATAKA", "KERALA", "KERALA", "KERALA", "KERALA", "KERALA", "KERALA", "KERALA", "KERALA", "KERALA", "KERALA", "KERALA", "KERALA", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "LAKSHADWEEP", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MADHYA PRADESH", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MAHARASHTRA", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MANIPUR", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MEGHALAYA", "MIZORAM", "MIZORAM", "MIZOR ...
